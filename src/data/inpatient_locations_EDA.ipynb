# %% [markdown]
# ## Inpatient Locations
#
# Dataset Information: Inpatient stay locations (when patient was placed in the specific unit, room, bed)

# %%
import pandas as pd
import os
import numpy as np
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import math

DATA_PATH = "../../../../bhatti/dataset/VCHAMPS"

# %%
dataset_path = 'inpatient_location_train.csv'
load_path = os.path.join(DATA_PATH, dataset_path)
location = pd.read_csv(load_path, index_col=0)

# %%
location[location["Internalpatientid"] == 100001]
# Out:
#        Internalpatientid  Age at location    Location start date  \
# 2048              100001        79.684170  2005-08-31 13:32:26.0
# 6148              100001        88.961766  2014-12-13 12:36:40.0
# 9216              100001        79.657711  2005-08-21 21:26:39.0
# 9217              100001        83.767138  2009-10-01 21:19:50.0
# 9218              100001        84.873295  2010-11-10 04:32:39.0
# 15360             100001        86.568969  2012-07-21 23:00:00.0
# 43009             100001        84.898357  2010-11-19 08:23:30.0
# 66562             100001        86.384955  2012-05-15 16:49:40.0
# 67584             100001        84.874240  2010-11-10 12:49:52.0
#
#            Location end date           Service Died at location  \
# 2048   2005-09-14 14:28:37.0  INTERMEDIATE MED               No
# 6148   2014-12-19 12:00:31.0          MEDICINE               No
# 9216   2005-08-31 13:39:33.0          MEDICINE               No
# 9217   2009-10-04 16:51:33.0          MEDICINE               No
# 9218   2010-11-10 13:00:33.0           SURGERY               No
# 15360  2012-07-22 19:18:48.0          MEDICINE               No
# 43009  2010-11-26 11:03:10.0              NHCU               No
# 66562  2012-05-19 14:06:53.0          MEDICINE               No
# 67584  2010-11-19 08:39:03.0           SURGERY               No
#
#                 State
# 2048   North Carolina
# 6148   North Carolina
# 9216   North Carolina
# 9217   North Carolina
# 9218   North Carolina
# 15360  North Carolina
# 43009  North Carolina
# 66562  North Carolina
# 67584  North Carolina

# %% [markdown]
# #### Service
#
# 1. Find the total number of times of unit stay for each patient
#
# 2. Change the service to one-hot
#
# 3. Number of **different** Service for each patient

# %% [markdown]
# #### Age at location
#
# 1. Length of unit stays

# %% [markdown]
# #### Start date and End date
#
# 1. Total length of stays

# %% [markdown]
# #### Died at location
#
# 1. Change to one-hot
