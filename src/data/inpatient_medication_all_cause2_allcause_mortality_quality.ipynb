# %%
import pandas as pd


import numpy as np
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

from datetime import datetime

# %%
path = '/data/public/MLA/VCHAMPS-Quality/medications_ordered_qual.csv'
medications = pd.read_csv(path).iloc[:,1:]
medications.head()
# Out:
#    Internalpatientid  Age at med ordered             Order date  \
# 0             100012           52.169740  2001-09-01 00:57:34.0
# 1             100012           52.188357  2001-09-07 20:15:48.0
# 2             100012           52.767740  2002-04-07 14:37:01.0
# 3             100012           52.934562  2002-06-07 13:58:52.0
# 4             100012           53.011336  2002-07-05 15:26:15.0
#
#    Medication start date   Medication stop date Order discontinue date  \
# 0  2001-09-01 00:57:34.0  2003-10-16 07:08:34.0  2002-01-06 16:07:34.0
# 1  2001-09-07 20:15:48.0  2001-11-07 07:08:48.0  2001-11-07 07:08:48.0
# 2  2002-04-10 09:55:01.0  2002-04-11 11:34:01.0  2002-04-11 11:34:01.0
# 3  2002-06-07 13:58:52.0  2002-07-07 13:58:52.0                    NaN
# 4  2002-07-05 15:26:15.0  2002-08-04 15:26:15.0                    NaN
#
#                   Ordered medication atc 5  Order status  \
# 0                             lansoprazole  discontinued
# 1                                celecoxib  discontinued
# 2                             benzalkonium     cancelled
# 3  oxycodone ; paracetamol (acetaminophen)       expired
# 4                         Not a medication       expired
#
#                 Stop reason       State
# 0  Not specified (no value)       Texas
# 1  Not specified (no value)       Texas
# 2  Not specified (no value)  New Mexico
# 3  Not specified (no value)  New Mexico
# 4  Not specified (no value)  New Mexico

# %%
medications['Order date'] = pd.to_datetime(medications['Order date'])
medications['Medication start date'] = pd.to_datetime(medications['Medication start date'])
medications['Medication stop date'] = pd.to_datetime(medications['Medication stop date'])

# %% [markdown]
# Keep order status == complete. For other order status,
#
# we can not make sure if the patient took medicines or not
#
# Though we will loss 99% data, we still have 997778 rows, that's enough?

# %%
medication_complete = medications.loc[medications['Order status'] == 'complete']
medication_complete = medication_complete.groupby('Internalpatientid').apply(lambda x:x).sort_values(by = ['Internalpatientid','Order date'],ascending=True).reset_index(drop = True)
medication_complete
# Out:
# /tmp/ipykernel_280902/2219256273.py:2: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   medication_complete = medication_complete.groupby('Internalpatientid').apply(lambda x:x).sort_values(by = ['Internalpatientid','Order date'],ascending=True).reset_index(drop = True)
#       Internalpatientid  Age at med ordered          Order date  \
# 0                    67           48.284700 2010-08-10 01:23:14
# 1                    67           48.284700 2010-08-10 01:23:14
# 2                    67           48.284704 2010-08-10 01:25:18
# 3                    67           49.301013 2011-08-16 12:29:00
# 4                    67           51.655025 2013-12-23 21:52:45
# ...                 ...                 ...                 ...
# 7401             168008           73.252908 2013-03-17 22:30:41
# 7402             168008           73.272166 2013-03-24 23:26:34
# 7403             168008           73.335228 2013-04-17 00:37:23
# 7404             168008           73.335598 2013-04-17 03:51:55
# 7405             168008           73.337837 2013-04-17 23:30:22
#
#      Medication start date Medication stop date Order discontinue date  \
# 0                      NaT  2010-08-10 01:38:14                    NaN
# 1                      NaT  2010-08-10 01:38:14                    NaN
# 2                      NaT  2010-08-10 01:38:18                    NaN
# 3                      NaT  2011-08-16 13:08:00                    NaN
# 4                      NaT  2013-12-23 22:11:45                    NaN
# ...                    ...                  ...                    ...
# 7401   2013-03-17 22:30:41  2013-03-19 05:43:41                    NaN
# 7402   2013-03-25 18:04:34  2013-03-28 18:19:34                    NaN
# 7403   2013-04-17 00:51:23  2013-04-17 04:41:23                    NaN
# 7404   2013-04-17 04:38:55  2013-04-17 23:25:55                    NaN
# 7405   2013-04-17 23:38:22  2013-04-18 01:08:22                    NaN
#
#                                Ordered medication atc 5 Order status  \
# 0                                        tetanus toxoid     complete
# 1                                    influenza vaccines     complete
# 2        pneumococcus, purified polysaccharides antigen     complete
# 3                                    influenza vaccines     complete
# 4     pneumococcus, purified polysaccharides antigen...     complete
# ...                                                 ...          ...
# 7401                                          lactulose     complete
# 7402                                     erythropoietin     complete
# 7403                                      hydromorphone     complete
# 7404                                      hydromorphone     complete
# 7405                                      hydromorphone     complete
#
#                    Stop reason       State
# 0     Not specified (no value)  California
# 1     Not specified (no value)  California
# 2     Not specified (no value)  California
# 3     Not specified (no value)  California
# 4     Not specified (no value)  California
# ...                        ...         ...
# 7401  Not specified (no value)       Texas
# 7402  Not specified (no value)       Texas
# 7403  Not specified (no value)       Texas
# 7404  Not specified (no value)       Texas
# 7405  Not specified (no value)       Texas
#
# [7406 rows x 10 columns]

# %%
path = '/home/hassan/lily/MLA/FDA/outpatient_mortality_quality.csv'
inpatient = pd.read_csv(path).iloc[:,1:]
inpatient.head()

inpatient_date = inpatient[['Internalpatientid','last_visit_date']]
inpatient_date = inpatient_date.drop_duplicates(keep = 'first')
inpatient_date = inpatient_date.rename(columns = {'last_visit_date':'Final discharge date'})
inpatient_date
# Out:
#      Internalpatientid   Final discharge date
# 0                   67  2020-11-11 16:00:31.0
# 1                  200  2023-02-13 10:31:19.0
# 2                  291  2007-03-26 14:15:45.0
# 3                  330  2024-03-01 00:19:37.0
# 4                  351  2024-06-04 14:45:34.0
# ..                 ...                    ...
# 995             167907  2013-11-14 23:44:48.0
# 996             167917  2022-01-27 05:25:51.0
# 997             168008  2013-12-03 23:38:48.0
# 998             168496  2023-02-03 22:36:15.0
# 999             168899  2019-11-20 03:24:47.0
#
# [1000 rows x 2 columns]

# %%
path = '/data/public/MLA/VCHAMPS-Quality/inpatient_admissions_qual_Formatfixed.csv'
inpatient2 = pd.read_csv(path).iloc[:,1:]
inpatient2_date = inpatient2[['Internalpatientid','Admission.date', 'Discharge.date']]
inpatient2_date = inpatient2_date.sort_values(
    by = 'Internalpatientid',ascending=True).reset_index(drop = True)
inpatient2_date
# Out:
#       Internalpatientid         Admission.date         Discharge.date
# 0                    67  2019-04-29 18:20:54.0  2019-04-29 22:39:20.0
# 1                   200  2012-12-30 00:04:08.0  2012-12-31 17:11:14.0
# 2                   200  2019-01-30 06:58:50.0  2019-01-31 22:59:02.0
# 3                   200  2019-06-11 11:49:31.0  2019-06-20 04:09:03.0
# 4                   200  2012-05-15 16:19:44.0  2012-05-28 23:24:45.0
# ...                 ...                    ...                    ...
# 4005             168008  2013-03-17 03:11:46.0  2013-03-19 05:36:38.0
# 4006             168008  2012-12-30 22:07:42.0  2013-01-01 22:50:15.0
# 4007             168008  2013-04-15 07:00:32.0  2013-04-16 05:39:59.0
# 4008             168008  2013-04-16 05:42:04.0  2013-04-18 17:41:26.0
# 4009             168008  2013-02-22 03:46:04.0  2013-02-24 12:35:13.0
#
# [4010 rows x 3 columns]

# %%
# Filter out admissions before discharge ddl
inpatient_dates = inpatient2_date.merge(inpatient_date, how = 'left', on = 'Internalpatientid')
inpatient_dates = inpatient_dates.loc[inpatient_dates['Discharge.date'] <= 
                                       inpatient_dates['Final discharge date']]
inpatient_dates
# Out:
#       Internalpatientid         Admission.date         Discharge.date  \
# 0                    67  2019-04-29 18:20:54.0  2019-04-29 22:39:20.0
# 1                   200  2012-12-30 00:04:08.0  2012-12-31 17:11:14.0
# 2                   200  2019-01-30 06:58:50.0  2019-01-31 22:59:02.0
# 3                   200  2019-06-11 11:49:31.0  2019-06-20 04:09:03.0
# 4                   200  2012-05-15 16:19:44.0  2012-05-28 23:24:45.0
# ...                 ...                    ...                    ...
# 4005             168008  2013-03-17 03:11:46.0  2013-03-19 05:36:38.0
# 4006             168008  2012-12-30 22:07:42.0  2013-01-01 22:50:15.0
# 4007             168008  2013-04-15 07:00:32.0  2013-04-16 05:39:59.0
# 4008             168008  2013-04-16 05:42:04.0  2013-04-18 17:41:26.0
# 4009             168008  2013-02-22 03:46:04.0  2013-02-24 12:35:13.0
#
#        Final discharge date
# 0     2020-11-11 16:00:31.0
# 1     2023-02-13 10:31:19.0
# 2     2023-02-13 10:31:19.0
# 3     2023-02-13 10:31:19.0
# 4     2023-02-13 10:31:19.0
# ...                     ...
# 4005  2013-12-03 23:38:48.0
# 4006  2013-12-03 23:38:48.0
# 4007  2013-12-03 23:38:48.0
# 4008  2013-12-03 23:38:48.0
# 4009  2013-12-03 23:38:48.0
#
# [3981 rows x 4 columns]

# %%
# Fill null values in start and stop date with order date
medication_complete['Medication start date'] = medication_complete['Medication start date'].fillna(medication_complete['Order date'])
medication_complete['Medication stop date'] = medication_complete['Medication stop date'].fillna(medication_complete['Order date'])

# %%
# Merge medication and inpatient table in order to 
# get number of medicaitons per admission
inpatient_med_complete = pd.merge(medication_complete, inpatient_dates, how = 'left', on = 'Internalpatientid')
inpatient_med_complete.head()
# Out:
#    Internalpatientid  Age at med ordered          Order date  \
# 0                 67           48.284700 2010-08-10 01:23:14
# 1                 67           48.284700 2010-08-10 01:23:14
# 2                 67           48.284704 2010-08-10 01:25:18
# 3                 67           49.301013 2011-08-16 12:29:00
# 4                 67           51.655025 2013-12-23 21:52:45
#
#   Medication start date Medication stop date Order discontinue date  \
# 0   2010-08-10 01:23:14  2010-08-10 01:38:14                    NaN
# 1   2010-08-10 01:23:14  2010-08-10 01:38:14                    NaN
# 2   2010-08-10 01:25:18  2010-08-10 01:38:18                    NaN
# 3   2011-08-16 12:29:00  2011-08-16 13:08:00                    NaN
# 4   2013-12-23 21:52:45  2013-12-23 22:11:45                    NaN
#
#                             Ordered medication atc 5 Order status  \
# 0                                     tetanus toxoid     complete
# 1                                 influenza vaccines     complete
# 2     pneumococcus, purified polysaccharides antigen     complete
# 3                                 influenza vaccines     complete
# 4  pneumococcus, purified polysaccharides antigen...     complete
#
#                 Stop reason       State         Admission.date  \
# 0  Not specified (no value)  California  2019-04-29 18:20:54.0
# 1  Not specified (no value)  California  2019-04-29 18:20:54.0
# 2  Not specified (no value)  California  2019-04-29 18:20:54.0
# 3  Not specified (no value)  California  2019-04-29 18:20:54.0
# 4  Not specified (no value)  California  2019-04-29 18:20:54.0
#
#           Discharge.date   Final discharge date
# 0  2019-04-29 22:39:20.0  2020-11-11 16:00:31.0
# 1  2019-04-29 22:39:20.0  2020-11-11 16:00:31.0
# 2  2019-04-29 22:39:20.0  2020-11-11 16:00:31.0
# 3  2019-04-29 22:39:20.0  2020-11-11 16:00:31.0
# 4  2019-04-29 22:39:20.0  2020-11-11 16:00:31.0

# %%
# Make each medication order to the corresponding admission
inpatient_med_complete2 = inpatient_med_complete.loc[(inpatient_med_complete['Medication start date'] >= inpatient_med_complete['Admission.date'])
                                                &(inpatient_med_complete['Medication start date'] <= inpatient_med_complete['Discharge.date'])
                                                &(inpatient_med_complete['Medication stop date'] >= inpatient_med_complete['Admission.date'])
                                                &(inpatient_med_complete['Medication stop date'] <= inpatient_med_complete['Discharge.date'])]

# %%
inpatient_med_complete2 = inpatient_med_complete2.drop_duplicates(subset = ['Internalpatientid','Medication start date','Ordered medication atc 5'],keep = 'first')
inpatient_med_complete2
# Out:
#         Internalpatientid  Age at med ordered          Order date  \
# 8                     200           77.061334 2012-05-15 22:01:24
# 13                    200           77.064466 2012-05-17 01:29:53
# 18                    200           77.069685 2012-05-18 23:16:29
# 23                    200           77.077003 2012-05-21 15:28:15
# 28                    200           77.079788 2012-05-22 15:54:10
# ...                   ...                 ...                 ...
# 111783             168008           73.188918 2013-02-22 13:11:11
# 111807             168008           73.272166 2013-03-24 23:26:34
# 111822             168008           73.335228 2013-04-17 00:37:23
# 111832             168008           73.335598 2013-04-17 03:51:55
# 111842             168008           73.337837 2013-04-17 23:30:22
#
#        Medication start date Medication stop date Order discontinue date  \
# 8        2012-05-16 02:32:24  2012-05-17 01:27:24                    NaN
# 13       2012-05-17 11:36:53  2012-05-18 16:22:53                    NaN
# 18       2012-05-19 15:51:29  2012-05-28 02:41:29                    NaN
# 23       2012-05-22 15:22:15  2012-05-28 02:12:15                    NaN
# 28       2012-05-23 03:09:10  2012-05-28 01:59:10                    NaN
# ...                      ...                  ...                    ...
# 111783   2013-02-23 03:46:11  2013-02-24 12:29:11                    NaN
# 111807   2013-03-25 18:04:34  2013-03-28 18:19:34                    NaN
# 111822   2013-04-17 00:51:23  2013-04-17 04:41:23                    NaN
# 111832   2013-04-17 04:38:55  2013-04-17 23:25:55                    NaN
# 111842   2013-04-17 23:38:22  2013-04-18 01:08:22                    NaN
#
#                 Ordered medication atc 5 Order status  \
# 8       ipratropium bromide ; salbutamol     complete
# 13                            metolazone     complete
# 18                             bisacodyl     complete
# 23                            lisinopril     complete
# 28                       magnesium oxide     complete
# ...                                  ...          ...
# 111783                sodium bicarbonate     complete
# 111807                    erythropoietin     complete
# 111822                     hydromorphone     complete
# 111832                     hydromorphone     complete
# 111842                     hydromorphone     complete
#
#                      Stop reason  State         Admission.date  \
# 8       Not specified (no value)   Utah  2012-05-15 16:19:44.0
# 13      Not specified (no value)   Utah  2012-05-15 16:19:44.0
# 18      Not specified (no value)   Utah  2012-05-15 16:19:44.0
# 23      Not specified (no value)   Utah  2012-05-15 16:19:44.0
# 28      Not specified (no value)   Utah  2012-05-15 16:19:44.0
# ...                          ...    ...                    ...
# 111783  Not specified (no value)  Texas  2013-02-22 03:46:04.0
# 111807  Not specified (no value)  Texas  2013-03-22 09:59:58.0
# 111822  Not specified (no value)  Texas  2013-04-16 05:42:04.0
# 111832  Not specified (no value)  Texas  2013-04-16 05:42:04.0
# 111842  Not specified (no value)  Texas  2013-04-16 05:42:04.0
#
#                Discharge.date   Final discharge date
# 8       2012-05-28 23:24:45.0  2023-02-13 10:31:19.0
# 13      2012-05-28 23:24:45.0  2023-02-13 10:31:19.0
# 18      2012-05-28 23:24:45.0  2023-02-13 10:31:19.0
# 23      2012-05-28 23:24:45.0  2023-02-13 10:31:19.0
# 28      2012-05-28 23:24:45.0  2023-02-13 10:31:19.0
# ...                       ...                    ...
# 111783  2013-02-24 12:35:13.0  2013-12-03 23:38:48.0
# 111807  2013-03-31 01:30:22.0  2013-12-03 23:38:48.0
# 111822  2013-04-18 17:41:26.0  2013-12-03 23:38:48.0
# 111832  2013-04-18 17:41:26.0  2013-12-03 23:38:48.0
# 111842  2013-04-18 17:41:26.0  2013-12-03 23:38:48.0
#
# [4225 rows x 13 columns]

# %%
# Calculate number of medication for each admission
tmp = pd.DataFrame(inpatient_med_complete2.groupby(['Internalpatientid', 'Admission.date'])['Ordered medication atc 5'].count())
tmp = tmp.reset_index(drop = False)
tmp = tmp.rename(columns = {'Ordered medication atc 5':'Num medication per admission'})
tmp
# Out:
#       Internalpatientid         Admission.date  Num medication per admission
# 0                   200  2012-05-15 16:19:44.0                             7
# 1                   200  2012-12-30 00:04:08.0                             1
# 2                   200  2019-06-11 11:49:31.0                             3
# 3                   291  2006-05-05 07:04:27.0                             1
# 4                   291  2006-05-20 14:06:35.0                             4
# ...                 ...                    ...                           ...
# 1424             167917  2015-07-12 07:43:34.0                             1
# 1425             167917  2016-08-05 05:50:51.0                             1
# 1426             168008  2013-02-22 03:46:04.0                             1
# 1427             168008  2013-03-22 09:59:58.0                             1
# 1428             168008  2013-04-16 05:42:04.0                             3
#
# [1429 rows x 3 columns]

# %%
inpatient_med_complete3 = inpatient_med_complete2.merge(tmp, how = 'left', on = ['Internalpatientid', 'Admission.date'])
inpatient_med_complete3['Total medications'] = inpatient_med_complete3['Num medication per admission'].groupby(inpatient_med_complete3['Internalpatientid']).transform('sum')
inpatient_med_complete3['Num med per admission mean'] = inpatient_med_complete3['Num medication per admission'].groupby(inpatient_med_complete3['Internalpatientid']).transform('mean')
inpatient_med_complete3['Num med per admission min'] = inpatient_med_complete3['Num medication per admission'].groupby(inpatient_med_complete3['Internalpatientid']).transform('min')
inpatient_med_complete3['Num med per admission max'] = inpatient_med_complete3['Num medication per admission'].groupby(inpatient_med_complete3['Internalpatientid']).transform('max')
inpatient_med_complete3
# Out:
#       Internalpatientid  Age at med ordered          Order date  \
# 0                   200           77.061334 2012-05-15 22:01:24
# 1                   200           77.064466 2012-05-17 01:29:53
# 2                   200           77.069685 2012-05-18 23:16:29
# 3                   200           77.077003 2012-05-21 15:28:15
# 4                   200           77.079788 2012-05-22 15:54:10
# ...                 ...                 ...                 ...
# 4220             168008           73.188918 2013-02-22 13:11:11
# 4221             168008           73.272166 2013-03-24 23:26:34
# 4222             168008           73.335228 2013-04-17 00:37:23
# 4223             168008           73.335598 2013-04-17 03:51:55
# 4224             168008           73.337837 2013-04-17 23:30:22
#
#      Medication start date Medication stop date Order discontinue date  \
# 0      2012-05-16 02:32:24  2012-05-17 01:27:24                    NaN
# 1      2012-05-17 11:36:53  2012-05-18 16:22:53                    NaN
# 2      2012-05-19 15:51:29  2012-05-28 02:41:29                    NaN
# 3      2012-05-22 15:22:15  2012-05-28 02:12:15                    NaN
# 4      2012-05-23 03:09:10  2012-05-28 01:59:10                    NaN
# ...                    ...                  ...                    ...
# 4220   2013-02-23 03:46:11  2013-02-24 12:29:11                    NaN
# 4221   2013-03-25 18:04:34  2013-03-28 18:19:34                    NaN
# 4222   2013-04-17 00:51:23  2013-04-17 04:41:23                    NaN
# 4223   2013-04-17 04:38:55  2013-04-17 23:25:55                    NaN
# 4224   2013-04-17 23:38:22  2013-04-18 01:08:22                    NaN
#
#               Ordered medication atc 5 Order status               Stop reason  \
# 0     ipratropium bromide ; salbutamol     complete  Not specified (no value)
# 1                           metolazone     complete  Not specified (no value)
# 2                            bisacodyl     complete  Not specified (no value)
# 3                           lisinopril     complete  Not specified (no value)
# 4                      magnesium oxide     complete  Not specified (no value)
# ...                                ...          ...                       ...
# 4220                sodium bicarbonate     complete  Not specified (no value)
# 4221                    erythropoietin     complete  Not specified (no value)
# 4222                     hydromorphone     complete  Not specified (no value)
# 4223                     hydromorphone     complete  Not specified (no value)
# 4224                     hydromorphone     complete  Not specified (no value)
#
#       State         Admission.date         Discharge.date  \
# 0      Utah  2012-05-15 16:19:44.0  2012-05-28 23:24:45.0
# 1      Utah  2012-05-15 16:19:44.0  2012-05-28 23:24:45.0
# 2      Utah  2012-05-15 16:19:44.0  2012-05-28 23:24:45.0
# 3      Utah  2012-05-15 16:19:44.0  2012-05-28 23:24:45.0
# 4      Utah  2012-05-15 16:19:44.0  2012-05-28 23:24:45.0
# ...     ...                    ...                    ...
# 4220  Texas  2013-02-22 03:46:04.0  2013-02-24 12:35:13.0
# 4221  Texas  2013-03-22 09:59:58.0  2013-03-31 01:30:22.0
# 4222  Texas  2013-04-16 05:42:04.0  2013-04-18 17:41:26.0
# 4223  Texas  2013-04-16 05:42:04.0  2013-04-18 17:41:26.0
# 4224  Texas  2013-04-16 05:42:04.0  2013-04-18 17:41:26.0
#
#        Final discharge date  Num medication per admission  Total medications  \
# 0     2023-02-13 10:31:19.0                             7                 59
# 1     2023-02-13 10:31:19.0                             7                 59
# 2     2023-02-13 10:31:19.0                             7                 59
# 3     2023-02-13 10:31:19.0                             7                 59
# 4     2023-02-13 10:31:19.0                             7                 59
# ...                     ...                           ...                ...
# 4220  2013-12-03 23:38:48.0                             1                 11
# 4221  2013-12-03 23:38:48.0                             1                 11
# 4222  2013-12-03 23:38:48.0                             3                 11
# 4223  2013-12-03 23:38:48.0                             3                 11
# 4224  2013-12-03 23:38:48.0                             3                 11
#
#       Num med per admission mean  Num med per admission min  \
# 0                       5.363636                          1
# 1                       5.363636                          1
# 2                       5.363636                          1
# 3                       5.363636                          1
# 4                       5.363636                          1
# ...                          ...                        ...
# 4220                    2.200000                          1
# 4221                    2.200000                          1
# 4222                    2.200000                          1
# 4223                    2.200000                          1
# 4224                    2.200000                          1
#
#       Num med per admission max
# 0                             7
# 1                             7
# 2                             7
# 3                             7
# 4                             7
# ...                         ...
# 4220                          3
# 4221                          3
# 4222                          3
# 4223                          3
# 4224                          3
#
# [4225 rows x 18 columns]

# %%
keep_columns = ['Internalpatientid','Num med per admission mean','Num med per admission min',
           'Num med per admission max','Total medications']

# %%
df = inpatient_med_complete3[keep_columns]
df = df.groupby('Internalpatientid').apply(lambda x:x)
df = df.drop_duplicates(keep = 'first').reset_index(drop = True)
df
# Out:
# /tmp/ipykernel_280902/2151990292.py:2: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df = df.groupby('Internalpatientid').apply(lambda x:x)
#      Internalpatientid  Num med per admission mean  Num med per admission min  \
# 0                  200                    5.363636                          1
# 1                  291                    3.250000                          1
# 2                  330                    1.000000                          1
# 3                  351                    3.857143                          1
# 4                  444                    1.666667                          1
# ..                 ...                         ...                        ...
# 446             166229                    4.120000                          1
# 447             166881                    2.000000                          2
# 448             167102                    2.000000                          2
# 449             167917                    1.000000                          1
# 450             168008                    2.200000                          1
#
#      Num med per admission max  Total medications
# 0                            7                 59
# 1                            4                 26
# 2                            1                  2
# 3                            5                 27
# 4                            2                  5
# ..                         ...                ...
# 446                          6                103
# 447                          2                  4
# 448                          2                  8
# 449                          1                  2
# 450                          3                 11
#
# [451 rows x 5 columns]

# %%
# df.to_csv('/home/daisy/FDA_Dataset/inpatient_medications_ordered_allcause_mortality_quality.csv')
