# %%
import pandas as pd


import numpy as np
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

from datetime import datetime

# %%
path = '/data/public/MLA/VCHAMPS-Test/medications_ordered_test.csv'
medications = pd.read_csv(path).iloc[:,1:]
medications.head()
# Out:
#    Internalpatientid  Age at med ordered             Order date  \
# 0                100           54.451524  2016-03-11 00:45:56.0
# 1                100           54.741514  2016-06-25 00:33:25.0
# 2                100           54.827014  2016-07-26 06:33:56.0
# 3                100           55.089929  2016-10-30 08:51:18.0
# 4                100           55.090329  2016-10-30 12:22:12.0
#
#    Medication start date   Medication stop date Order discontinue date  \
# 0  2016-03-11 10:57:56.0  2016-12-25 00:40:56.0  2016-12-25 00:40:56.0
# 1  2016-06-24 09:39:25.0  2016-07-09 01:15:25.0  2016-07-09 01:15:25.0
# 2                    NaN  2016-12-26 05:34:56.0  2016-12-26 05:34:56.0
# 3  2016-10-30 08:54:18.0  2016-10-31 09:36:18.0  2016-10-31 09:36:18.0
# 4  2016-10-30 12:22:12.0  2016-10-30 21:39:12.0                    NaN
#
#          Ordered medication atc 5  Order status  \
# 0               hydrogen peroxide  discontinued
# 1                     guaifenesin  discontinued
# 2  dextromethorphan ; guaifenesin  discontinued
# 3                        riluzole  discontinued
# 4              potassium chloride       expired
#
#                       Stop reason     State
# 0  Requesting Physician Cancelled  New York
# 1                  Obsolete Order  New York
# 2  Requesting Physician Cancelled  New York
# 3  Requesting Physician Cancelled  New York
# 4        Not specified (no value)  New York

# %%
medications['Order date'] = pd.to_datetime(medications['Order date'])
medications['Medication start date'] = pd.to_datetime(medications['Medication start date'])
medications['Medication stop date'] = pd.to_datetime(medications['Medication stop date'])

# %% [markdown]
# Keep order status == complete. For other order status,
#
# we can not make sure if the patient took medicines or not
#
# Though we will loss 99% data, we still have 997778 rows, that's enough?

# %%
medication_complete = medications.loc[medications['Order status'] == 'complete']
medication_complete = medication_complete.groupby('Internalpatientid').apply(lambda x:x).sort_values(by = ['Internalpatientid','Order date'],ascending=True).reset_index(drop = True)
medication_complete
# Out:
# /tmp/ipykernel_265725/2219256273.py:2: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   medication_complete = medication_complete.groupby('Internalpatientid').apply(lambda x:x).sort_values(by = ['Internalpatientid','Order date'],ascending=True).reset_index(drop = True)
#         Internalpatientid  Age at med ordered          Order date  \
# 0                       6           79.393879 2006-01-29 11:06:34
# 1                       6           80.342664 2007-01-11 05:50:47
# 2                       6           80.342664 2007-01-11 05:50:47
# 3                       6           81.338677 2008-01-10 06:52:20
# 4                       6           81.338677 2008-01-10 06:52:20
# ...                   ...                 ...                 ...
# 268118             169065           53.266147 2011-05-22 18:38:35
# 268119             169065           53.268471 2011-05-23 15:01:45
# 268120             169065           53.282232 2011-05-28 15:44:17
# 268121             169065           53.293074 2011-06-01 14:50:31
# 268122             169065           53.316444 2011-06-10 03:50:39
#
#        Medication start date Medication stop date Order discontinue date  \
# 0                        NaT  2006-01-29 11:06:34                    NaN
# 1                        NaT  2007-01-11 05:50:47                    NaN
# 2                        NaT  2007-01-11 05:50:47                    NaN
# 3                        NaT  2008-01-10 06:57:20                    NaN
# 4                        NaT  2008-01-10 06:57:20                    NaN
# ...                      ...                  ...                    ...
# 268118   2011-05-22 20:34:35  2011-05-23 11:49:35                    NaN
# 268119   2011-05-24 10:34:45  2011-05-26 03:34:45                    NaN
# 268120   2011-05-29 10:44:17  2011-05-30 15:46:17                    NaN
# 268121                   NaT  2011-06-01 14:53:31                    NaN
# 268122   2011-06-10 10:26:39  2011-06-11 18:56:39                    NaN
#
#        Ordered medication atc 5 Order status               Stop reason  \
# 0                  moxifloxacin     complete  Not specified (no value)
# 1                    furosemide     complete  Not specified (no value)
# 2                    lisinopril     complete  Not specified (no value)
# 3                  azithromycin     complete  Not specified (no value)
# 4                   guaifenesin     complete  Not specified (no value)
# ...                         ...          ...                       ...
# 268118      aluminium hydroxide     complete  Not specified (no value)
# 268119                diltiazem     complete  Not specified (no value)
# 268120               vancomycin     complete  Not specified (no value)
# 268121                  heparin     complete  Not specified (no value)
# 268122               salbutamol     complete  Not specified (no value)
#
#           State
# 0         Texas
# 1         Texas
# 2         Texas
# 3         Texas
# 4         Texas
# ...         ...
# 268118  Arizona
# 268119  Arizona
# 268120  Arizona
# 268121  Arizona
# 268122  Arizona
#
# [268123 rows x 10 columns]

# %%
# path = '/home/hassan/lily/MLA/FDA/inpatient_full_simple.csv'
# inpatient = pd.read_csv(path).iloc[:,1:]
# inpatient.head()

# inpatient_date = inpatient[['Internalpatientid','Discharge date']]
# inpatient_date = inpatient_date.drop_duplicates(keep = 'first')
# inpatient_date = inpatient_date.rename(columns = {'Discharge date':'Final discharge date'})
# inpatient_date

# %%
path = '/data/public/MLA/VCHAMPS-Test/inpatient_admissions_test.csv'
inpatient2 = pd.read_csv(path).iloc[:,1:]
inpatient2_date = inpatient2[['Internalpatientid','Admission date', 'Discharge date']]
inpatient2_date = inpatient2_date.sort_values(
    by = 'Internalpatientid',ascending=True).reset_index(drop = True)
inpatient2_date
# Out:
#         Internalpatientid         Admission date         Discharge date
# 0                       7  2003-08-19 00:37:18.0  2003-08-19 23:32:28.0
# 1                       7  2007-08-15 18:19:23.0  2007-08-26 16:28:46.0
# 2                       7  2007-08-26 16:30:53.0  2007-09-23 17:14:50.0
# 3                       7  2014-03-23 08:01:03.0  2014-03-25 11:20:29.0
# 4                       7  2009-09-20 03:33:21.0  2009-09-22 09:26:12.0
# ...                   ...                    ...                    ...
# 139081             169065  1997-12-28 06:46:22.0  1997-12-29 07:14:14.0
# 139082             169065  2002-07-10 17:34:24.0  2002-07-24 19:50:33.0
# 139083             169065  2002-05-01 20:35:57.0  2002-05-06 19:27:54.0
# 139084             169065  2000-11-16 04:11:11.0  2000-11-25 07:38:10.0
# 139085             169065  2011-05-11 16:22:20.0  2011-06-11 16:37:13.0
#
# [139086 rows x 3 columns]

# %%
# Filter out admissions before discharge ddl
# inpatient_dates = inpatient2_date.merge(inpatient_date, how = 'left', on = 'Internalpatientid')
# inpatient_dates = inpatient_dates.loc[inpatient_dates['Discharge date'] <= 
#                                        inpatient_dates['Final discharge date']]
# inpatient_dates

# %%
# Fill null values in start and stop date with order date
medication_complete['Medication start date'] = medication_complete['Medication start date'].fillna(medication_complete['Order date'])
medication_complete['Medication stop date'] = medication_complete['Medication stop date'].fillna(medication_complete['Order date'])

# %%
# Merge medication and inpatient table in order to 
# get number of medicaitons per admission
inpatient_med_complete = pd.merge(medication_complete, inpatient2_date, how = 'left', on = 'Internalpatientid')
inpatient_med_complete.head()
# Out:
#    Internalpatientid  Age at med ordered          Order date  \
# 0                  6           79.393879 2006-01-29 11:06:34
# 1                  6           80.342664 2007-01-11 05:50:47
# 2                  6           80.342664 2007-01-11 05:50:47
# 3                  6           81.338677 2008-01-10 06:52:20
# 4                  6           81.338677 2008-01-10 06:52:20
#
#   Medication start date Medication stop date Order discontinue date  \
# 0   2006-01-29 11:06:34  2006-01-29 11:06:34                    NaN
# 1   2007-01-11 05:50:47  2007-01-11 05:50:47                    NaN
# 2   2007-01-11 05:50:47  2007-01-11 05:50:47                    NaN
# 3   2008-01-10 06:52:20  2008-01-10 06:57:20                    NaN
# 4   2008-01-10 06:52:20  2008-01-10 06:57:20                    NaN
#
#   Ordered medication atc 5 Order status               Stop reason  State  \
# 0             moxifloxacin     complete  Not specified (no value)  Texas
# 1               furosemide     complete  Not specified (no value)  Texas
# 2               lisinopril     complete  Not specified (no value)  Texas
# 3             azithromycin     complete  Not specified (no value)  Texas
# 4              guaifenesin     complete  Not specified (no value)  Texas
#
#   Admission date Discharge date
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN

# %%
# Make each medication order to the corresponding admission
inpatient_med_complete2 = inpatient_med_complete.loc[(inpatient_med_complete['Medication start date'] >= inpatient_med_complete['Admission date'])
                                                &(inpatient_med_complete['Medication start date'] <= inpatient_med_complete['Discharge date'])
                                                &(inpatient_med_complete['Medication stop date'] >= inpatient_med_complete['Admission date'])
                                                &(inpatient_med_complete['Medication stop date'] <= inpatient_med_complete['Discharge date'])]

# %%
inpatient_med_complete2 = inpatient_med_complete2.drop_duplicates(subset = ['Internalpatientid','Medication start date','Ordered medication atc 5'],keep = 'first')
inpatient_med_complete2
# Out:
#          Internalpatientid  Age at med ordered          Order date  \
# 21                      12           69.912449 2000-05-10 00:00:19
# 34                      12           71.931643 2002-05-18 00:22:32
# 40                      12           71.932109 2002-05-18 04:27:45
# 43                      12           72.185439 2002-08-18 18:40:06
# 62                      12           73.812482 2004-04-04 11:05:39
# ...                    ...                 ...                 ...
# 3602576             169065           53.257554 2011-05-19 15:16:00
# 3602590             169065           53.266147 2011-05-22 18:38:35
# 3602604             169065           53.268471 2011-05-23 15:01:45
# 3602618             169065           53.282232 2011-05-28 15:44:17
# 3602632             169065           53.293074 2011-06-01 14:50:31
#
#         Medication start date Medication stop date Order discontinue date  \
# 21        2000-05-10 12:22:19  2000-05-13 20:38:19                    NaN
# 34        2002-05-18 19:39:32  2002-05-20 02:19:32                    NaN
# 40        2002-05-18 19:35:45  2002-05-20 02:15:45                    NaN
# 43        2002-08-19 10:21:06  2002-08-19 10:22:06                    NaN
# 62        2004-04-05 10:13:39  2004-04-07 03:39:39                    NaN
# ...                       ...                  ...                    ...
# 3602576   2011-05-20 12:50:00  2011-05-23 03:50:00                    NaN
# 3602590   2011-05-22 20:34:35  2011-05-23 11:49:35                    NaN
# 3602604   2011-05-24 10:34:45  2011-05-26 03:34:45                    NaN
# 3602618   2011-05-29 10:44:17  2011-05-30 15:46:17                    NaN
# 3602632   2011-06-01 14:50:31  2011-06-01 14:53:31                    NaN
#
#         Ordered medication atc 5 Order status               Stop reason  \
# 21          acetylsalicylic acid     complete  Not specified (no value)
# 34          acetylsalicylic acid     complete  Not specified (no value)
# 40                  gatifloxacin     complete  Not specified (no value)
# 43                   ceftriaxone     complete  Not specified (no value)
# 62                   simvastatin     complete  Not specified (no value)
# ...                          ...          ...                       ...
# 3602576             pantoprazole     complete  Not specified (no value)
# 3602590      aluminium hydroxide     complete  Not specified (no value)
# 3602604                diltiazem     complete  Not specified (no value)
# 3602618               vancomycin     complete  Not specified (no value)
# 3602632                  heparin     complete  Not specified (no value)
#
#             State         Admission date         Discharge date
# 21       Colorado  2000-05-09 15:42:38.0  2000-05-13 20:49:23.0
# 34       Colorado  2002-05-18 00:04:03.0  2002-05-20 02:19:32.0
# 40       Colorado  2002-05-18 00:04:03.0  2002-05-20 02:19:32.0
# 43           Utah  2002-08-15 19:42:40.0  2002-08-26 10:54:34.0
# 62       Colorado  2004-04-04 10:59:02.0  2004-04-07 03:40:16.0
# ...           ...                    ...                    ...
# 3602576   Arizona  2011-05-11 16:22:20.0  2011-06-11 16:37:13.0
# 3602590   Arizona  2011-05-11 16:22:20.0  2011-06-11 16:37:13.0
# 3602604   Arizona  2011-05-11 16:22:20.0  2011-06-11 16:37:13.0
# 3602618   Arizona  2011-05-11 16:22:20.0  2011-06-11 16:37:13.0
# 3602632   Arizona  2011-05-11 16:22:20.0  2011-06-11 16:37:13.0
#
# [156241 rows x 12 columns]

# %%
# Calculate number of medication for each admission
tmp = pd.DataFrame(inpatient_med_complete2.groupby(['Internalpatientid', 'Admission date'])['Ordered medication atc 5'].count())
tmp = tmp.reset_index(drop = False)
tmp = tmp.rename(columns = {'Ordered medication atc 5':'Num medication per admission'})
tmp
# Out:
#        Internalpatientid         Admission date  Num medication per admission
# 0                     12  2000-05-09 15:42:38.0                             1
# 1                     12  2002-05-18 00:04:03.0                             2
# 2                     12  2002-08-15 19:42:40.0                             1
# 3                     12  2004-04-04 10:59:02.0                             4
# 4                     17  2004-04-30 13:43:25.0                             1
# ...                  ...                    ...                           ...
# 53118             168995  2008-03-24 11:26:58.0                             2
# 53119             169037  2015-02-12 01:22:46.0                             2
# 53120             169065  2005-07-11 20:22:23.0                             1
# 53121             169065  2011-04-10 00:33:11.0                             1
# 53122             169065  2011-05-11 16:22:20.0                             6
#
# [53123 rows x 3 columns]

# %%
inpatient_med_complete3 = inpatient_med_complete2.merge(tmp, how = 'left', on = ['Internalpatientid', 'Admission date'])
inpatient_med_complete3['Total medications'] = inpatient_med_complete3['Num medication per admission'].groupby(inpatient_med_complete3['Internalpatientid']).transform('sum')
inpatient_med_complete3['Num med per admission mean'] = inpatient_med_complete3['Num medication per admission'].groupby(inpatient_med_complete3['Internalpatientid']).transform('mean')
inpatient_med_complete3['Num med per admission min'] = inpatient_med_complete3['Num medication per admission'].groupby(inpatient_med_complete3['Internalpatientid']).transform('min')
inpatient_med_complete3['Num med per admission max'] = inpatient_med_complete3['Num medication per admission'].groupby(inpatient_med_complete3['Internalpatientid']).transform('max')
inpatient_med_complete3
# Out:
#         Internalpatientid  Age at med ordered          Order date  \
# 0                      12           69.912449 2000-05-10 00:00:19
# 1                      12           71.931643 2002-05-18 00:22:32
# 2                      12           71.932109 2002-05-18 04:27:45
# 3                      12           72.185439 2002-08-18 18:40:06
# 4                      12           73.812482 2004-04-04 11:05:39
# ...                   ...                 ...                 ...
# 156236             169065           53.257554 2011-05-19 15:16:00
# 156237             169065           53.266147 2011-05-22 18:38:35
# 156238             169065           53.268471 2011-05-23 15:01:45
# 156239             169065           53.282232 2011-05-28 15:44:17
# 156240             169065           53.293074 2011-06-01 14:50:31
#
#        Medication start date Medication stop date Order discontinue date  \
# 0        2000-05-10 12:22:19  2000-05-13 20:38:19                    NaN
# 1        2002-05-18 19:39:32  2002-05-20 02:19:32                    NaN
# 2        2002-05-18 19:35:45  2002-05-20 02:15:45                    NaN
# 3        2002-08-19 10:21:06  2002-08-19 10:22:06                    NaN
# 4        2004-04-05 10:13:39  2004-04-07 03:39:39                    NaN
# ...                      ...                  ...                    ...
# 156236   2011-05-20 12:50:00  2011-05-23 03:50:00                    NaN
# 156237   2011-05-22 20:34:35  2011-05-23 11:49:35                    NaN
# 156238   2011-05-24 10:34:45  2011-05-26 03:34:45                    NaN
# 156239   2011-05-29 10:44:17  2011-05-30 15:46:17                    NaN
# 156240   2011-06-01 14:50:31  2011-06-01 14:53:31                    NaN
#
#        Ordered medication atc 5 Order status               Stop reason  \
# 0          acetylsalicylic acid     complete  Not specified (no value)
# 1          acetylsalicylic acid     complete  Not specified (no value)
# 2                  gatifloxacin     complete  Not specified (no value)
# 3                   ceftriaxone     complete  Not specified (no value)
# 4                   simvastatin     complete  Not specified (no value)
# ...                         ...          ...                       ...
# 156236             pantoprazole     complete  Not specified (no value)
# 156237      aluminium hydroxide     complete  Not specified (no value)
# 156238                diltiazem     complete  Not specified (no value)
# 156239               vancomycin     complete  Not specified (no value)
# 156240                  heparin     complete  Not specified (no value)
#
#            State         Admission date         Discharge date  \
# 0       Colorado  2000-05-09 15:42:38.0  2000-05-13 20:49:23.0
# 1       Colorado  2002-05-18 00:04:03.0  2002-05-20 02:19:32.0
# 2       Colorado  2002-05-18 00:04:03.0  2002-05-20 02:19:32.0
# 3           Utah  2002-08-15 19:42:40.0  2002-08-26 10:54:34.0
# 4       Colorado  2004-04-04 10:59:02.0  2004-04-07 03:40:16.0
# ...          ...                    ...                    ...
# 156236   Arizona  2011-05-11 16:22:20.0  2011-06-11 16:37:13.0
# 156237   Arizona  2011-05-11 16:22:20.0  2011-06-11 16:37:13.0
# 156238   Arizona  2011-05-11 16:22:20.0  2011-06-11 16:37:13.0
# 156239   Arizona  2011-05-11 16:22:20.0  2011-06-11 16:37:13.0
# 156240   Arizona  2011-05-11 16:22:20.0  2011-06-11 16:37:13.0
#
#         Num medication per admission  Total medications  \
# 0                                  1                 22
# 1                                  2                 22
# 2                                  2                 22
# 3                                  1                 22
# 4                                  4                 22
# ...                              ...                ...
# 156236                             6                 38
# 156237                             6                 38
# 156238                             6                 38
# 156239                             6                 38
# 156240                             6                 38
#
#         Num med per admission mean  Num med per admission min  \
# 0                             2.75                          1
# 1                             2.75                          1
# 2                             2.75                          1
# 3                             2.75                          1
# 4                             2.75                          1
# ...                            ...                        ...
# 156236                        4.75                          1
# 156237                        4.75                          1
# 156238                        4.75                          1
# 156239                        4.75                          1
# 156240                        4.75                          1
#
#         Num med per admission max
# 0                               4
# 1                               4
# 2                               4
# 3                               4
# 4                               4
# ...                           ...
# 156236                          6
# 156237                          6
# 156238                          6
# 156239                          6
# 156240                          6
#
# [156241 rows x 17 columns]

# %%
keep_columns = ['Internalpatientid','Num med per admission mean','Num med per admission min',
           'Num med per admission max','Total medications']

# %%
df = inpatient_med_complete3[keep_columns]
df = df.groupby('Internalpatientid').apply(lambda x:x)
df = df.drop_duplicates(keep = 'first').reset_index(drop = True)
df
# Out:
# /tmp/ipykernel_265725/2151990292.py:2: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df = df.groupby('Internalpatientid').apply(lambda x:x)
#        Internalpatientid  Num med per admission mean  \
# 0                     12                    2.750000
# 1                     17                    2.500000
# 2                     25                    2.714286
# 3                     31                    2.000000
# 4                     41                    3.800000
# ...                  ...                         ...
# 16426             168969                    5.857143
# 16427             168988                    3.333333
# 16428             168995                    2.000000
# 16429             169037                    2.000000
# 16430             169065                    4.750000
#
#        Num med per admission min  Num med per admission max  Total medications
# 0                              1                          4                 22
# 1                              1                          3                 10
# 2                              1                          3                 19
# 3                              2                          2                  4
# 4                              2                          5                 38
# ...                          ...                        ...                ...
# 16426                          1                         10                164
# 16427                          2                          4                 20
# 16428                          2                          2                  4
# 16429                          2                          2                  4
# 16430                          1                          6                 38
#
# [16431 rows x 5 columns]

# %%
df.to_csv('/home/daisy/FDA_Dataset/inpatient_medications_ordered_cvd_mortality_test.csv')
