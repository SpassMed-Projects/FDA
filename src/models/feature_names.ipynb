# %%
import pandas as pd


import numpy as np
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 1. All cause admission left join:
path = '/home/daisy/FDA_Dataset/inpatient_all_final_test_1.csv'
inpatient_ad_test_1 = pd.read_csv(path).iloc[:,1:]

# All cause admission inner join
path = '/home/daisy/FDA_Dataset/inpatient_all_final_test_2.csv'
inpatient_ad_test_2 = pd.read_csv(path).iloc[:,1:]

# 2. CVD admission left join
path = '/home/daisy/FDA_Dataset/inpatient_CVD_final_test_1.csv'
inpatient_ad_cvd_test_1 = pd.read_csv(path).iloc[:,1:]

#  CVD admission inner join
path = '/home/daisy/FDA_Dataset/inpatient_CVD_final_test_2.csv'
inpatient_ad_cvd_test_2 = pd.read_csv(path).iloc[:,1:]

# 3. For CVD mortality	
# left join:
path = '/home/daisy/FDA_Dataset/final_cvd_mortality_test_1.csv'
inpatient_mortality_cvd_test_1 = pd.read_csv(path).iloc[:,1:]

# inner join:
path = '/home/daisy/FDA_Dataset/final_cvd_mortality_test_2.csv'
inpatient_mortality_cvd_test_2 = pd.read_csv(path).iloc[:,1:]

# 4. For all cause mortality
# left join
path = '/home/daisy/FDA_Dataset/final_allcause_mortality_test_1.csv'
inpatient_mortality_all_test_1 = pd.read_csv(path).iloc[:,1:]

# inner join
path = '/home/daisy/FDA_Dataset/final_allcause_mortality_test_2.csv'
inpatient_mortality_all_test_2 = pd.read_csv(path).iloc[:,1:]

# %%
path = '/home/daisy/FDA_Dataset/inpatient_CVD_final_test_1.csv'
inpatient_ad_cvd_test_1 = pd.read_csv(path).iloc[:,1:]

path = '/home/daisy/FDA_Dataset/inpatient_CVD_final_1.csv'
inpatient_ad_cvd_train_1 = pd.read_csv(path).iloc[:,1:]

# %%
pd.DataFrame({'train':inpatient_ad_cvd_train_1.columns,'test':inpatient_ad_cvd_test_1.columns})
# Out:
#                   train                 test
# 0     Internalpatientid    Internalpatientid
# 1             num_stays            num_stays
# 2           stay_length          stay_length
# 3      num_unique_units     num_unique_units
# 4         num_transfers        num_transfers
# ..                  ...                  ...
# 81               Weight               Weight
# 82   Pulse oximetry min   Pulse oximetry min
# 83   Pulse oximetry max   Pulse oximetry max
# 84  Pulse oximetry mean  Pulse oximetry mean
# 85   Pulse oximetry std   Pulse oximetry std
#
# [86 rows x 2 columns]

# %%
feature_dict_ad_test = {
    'inpatient_ad_test_1':inpatient_ad_test_1.columns,
    'inpatient_ad_test_2':inpatient_ad_test_2.columns}
feature_dict_ad_cvd_test = {
    'inpatient_ad_cvd_test_1':inpatient_ad_cvd_test_1.columns,
    'inpatient_ad_cvd_test_2':inpatient_ad_cvd_test_2.columns}
feature_dict_mortality_cvd_test = {
    'inpatient_mortality_cvd_test_1':inpatient_mortality_cvd_test_1.columns,
    'inpatient_mortality_cvd_test_2':inpatient_mortality_cvd_test_2.columns}
feature_dict_mortality_all_test = {
    'inpatient_mortality_all_test_1':inpatient_mortality_all_test_1.columns,
    'inpatient_mortality_all_test_2':inpatient_mortality_all_test_2.columns
}
df1 = pd.DataFrame(feature_dict_ad_test)
df2 = pd.DataFrame(feature_dict_ad_cvd_test)
df3 = pd.DataFrame(feature_dict_mortality_cvd_test)
df4 = pd.DataFrame(feature_dict_mortality_all_test)

df = pd.concat([df1, df2, df3, df4],axis = 1)
pd.set_option('display.max_rows', df.shape[0]+1)
df
# Out:
#              inpatient_ad_test_1           inpatient_ad_test_2  \
# 0              Internalpatientid             Internalpatientid
# 1                      num_stays                     num_stays
# 2                    stay_length                   stay_length
# 3               num_unique_units              num_unique_units
# 4                  num_transfers                 num_transfers
# 5              num_cvd_admission             num_cvd_admission
# 6                            CVD                           CVD
# 7     unique_admitting_specialty    unique_admitting_specialty
# 8   unique_discharging_specialty  unique_discharging_specialty
# 9                    DOMICILIARY                   DOMICILIARY
# 10                      MEDICINE                      MEDICINE
# 11                          NHCU                          NHCU
# 12                     NON-COUNT                     NON-COUNT
# 13                        OTHERS                        OTHERS
# ...

# %%
# 1. For admission :
# 1. All cause admission left join:
path = '/home/daisy/FDA_Dataset/inpatient_all_final_1.csv'
inpatient_ad_train_1 = pd.read_csv(path).iloc[:,1:]

# 2. All cause admission inner join
path = '/home/daisy/FDA_Dataset/inpatient_all_final_2.csv'
inpatient_ad_train_2 = pd.read_csv(path).iloc[:,1:]

# 3. CVD admission left join
path = '/home/daisy/FDA_Dataset/inpatient_CVD_final_1.csv'
inpatient_ad_cvd_train_1 = pd.read_csv(path).iloc[:,1:]

# 4. CVD admission inner join
path = '/home/daisy/FDA_Dataset/inpatient_CVD_final_2.csv'
inpatient_ad_cvd_train_2 = pd.read_csv(path).iloc[:,1:]

# 2. For CVD mortality	
# left join:
path = '/home/daisy/FDA_Dataset/final_cvd_mortality_train_1.csv'
inpatient_mortality_cvd_train_1 = pd.read_csv(path).iloc[:,1:]

# inner join:
path = '/home/daisy/FDA_Dataset/final_cvd_mortality_train_2.csv'
inpatient_mortality_cvd_train_2 = pd.read_csv(path).iloc[:,1:]

#3. For all cause mortality
# left join
path = '/home/daisy/FDA_Dataset/final_allcause_mortality_train_1.csv'
inpatient_mortality_all_train_1 = pd.read_csv(path).iloc[:,1:]

# inner join
path = '/home/daisy/FDA_Dataset/final_allcause_mortality_train_2.csv'
inpatient_mortality_all_train_2 = pd.read_csv(path).iloc[:,1:]

# %%
feature_dict_ad_train = {
    'inpatient_ad_train_1':inpatient_ad_train_1.columns,
    'inpatient_ad_train_2':inpatient_ad_train_2.columns}
feature_dict_ad_cvd_train = {
    'inpatient_ad_cvd_train_1':inpatient_ad_cvd_train_1.columns,
    'inpatient_ad_cvd_train_2':inpatient_ad_cvd_train_2.columns}
feature_dict_mortality_cvd_train = {
    'inpatient_mortality_cvd_train_1':inpatient_mortality_cvd_train_1.columns,
    'inpatient_mortality_cvd_train_2':inpatient_mortality_cvd_train_2.columns}
feature_dict_mortality_all_train = {
    'inpatient_mortality_all_train_1':inpatient_mortality_all_train_1.columns,
    'inpatient_mortality_all_train_2':inpatient_mortality_all_train_2.columns
}
df1 = pd.DataFrame(feature_dict_ad_train)
df2 = pd.DataFrame(feature_dict_ad_cvd_train)
df3 = pd.DataFrame(feature_dict_mortality_cvd_train)
df4 = pd.DataFrame(feature_dict_mortality_all_train)

df = pd.concat([df1, df2, df3, df4],axis = 1)
pd.set_option('display.max_rows', df.shape[0]+1)
df
# Out:
#             inpatient_ad_train_1          inpatient_ad_train_2  \
# 0              Internalpatientid             Internalpatientid
# 1                      num_stays                     num_stays
# 2                    stay_length                   stay_length
# 3               num_unique_units              num_unique_units
# 4                  num_transfers                 num_transfers
# 5              num_cvd_admission             num_cvd_admission
# 6                            CVD                           CVD
# 7     unique_admitting_specialty    unique_admitting_specialty
# 8   unique_discharging_specialty  unique_discharging_specialty
# 9                    DOMICILIARY                   DOMICILIARY
# 10                      MEDICINE                      MEDICINE
# 11                          NHCU                          NHCU
# 12                     NON-COUNT                     NON-COUNT
# 13                        OTHERS                        OTHERS
# ...

# %%
# For admission 
# 1. All cause admission left join:
path = '/home/daisy/FDA_Dataset/inpatient_all_final_quality_admission_1.csv'
inpatient_ad_quality_1 = pd.read_csv(path).iloc[:,1:]

# 2. All cause admission inner join
path = '/home/daisy/FDA_Dataset/inpatient_all_final_quality_admission_2.csv'
inpatient_ad_quality_2 = pd.read_csv(path).iloc[:,1:]

# 3. CVD admission left join
path = '/home/daisy/FDA_Dataset/inpatient_CVD_final_quality_admission_1.csv'
inpatient_ad_cvd_quality_1 = pd.read_csv(path).iloc[:,1:]
	
# 4. CVD admission inner join
path = '/home/daisy/FDA_Dataset/inpatient_CVD_final_quality_admission_2.csv'
inpatient_ad_cvd_quality_2 = pd.read_csv(path).iloc[:,1:]

# 2. For CVD mortality	
# left join:
path = '/home/daisy/FDA_Dataset/final_cvd_mortality_quality_1.csv'
inpatient_mortality_cvd_quality_1 = pd.read_csv(path).iloc[:,1:]

# inner join:
path = '/home/daisy/FDA_Dataset/final_cvd_mortality_quality_2.csv'
inpatient_mortality_cvd_quality_2 = pd.read_csv(path).iloc[:,1:]

# 3. For all cause mortality
# left join
path = '/home/daisy/FDA_Dataset/final_allcause_mortality_quality_1.csv'
inpatient_mortality_all_quality_1 = pd.read_csv(path).iloc[:,1:]
		
# inner join
path = '/home/daisy/FDA_Dataset/final_allcause_mortality_quality_2.csv'
inpatient_mortality_all_quality_2 = pd.read_csv(path).iloc[:,1:]

# %%
feature_dict_ad_quality = {
    'inpatient_ad_quality_1':inpatient_ad_quality_1.columns,
    'inpatient_ad_quality_2':inpatient_ad_quality_2.columns}
feature_dict_ad_cvd_quality = {
    'inpatient_ad_cvd_quality_1':inpatient_ad_cvd_quality_1.columns,
    'inpatient_ad_cvd_quality_2':inpatient_ad_cvd_quality_2.columns}
feature_dict_mortality_cvd_quality = {
    'inpatient_mortality_cvd_quality_1':inpatient_mortality_cvd_quality_1.columns,
    'inpatient_mortality_cvd_quality_2':inpatient_mortality_cvd_quality_2.columns}
feature_dict_mortality_all_quality = {
    'inpatient_mortality_all_quality_1':inpatient_mortality_all_quality_1.columns,
    'inpatient_mortality_all_quality_2':inpatient_mortality_all_quality_2.columns
}
df1 = pd.DataFrame(feature_dict_ad_quality)
df2 = pd.DataFrame(feature_dict_ad_cvd_quality)
df3 = pd.DataFrame(feature_dict_mortality_cvd_quality)
df4 = pd.DataFrame(feature_dict_mortality_all_quality)

df = pd.concat([df1, df2, df3, df4],axis = 1)
pd.set_option('display.max_rows', df.shape[0]+1)
df
# Out:
#           inpatient_ad_quality_1        inpatient_ad_quality_2  \
# 0              Internalpatientid             Internalpatientid
# 1                      num_stays                     num_stays
# 2                    stay_length                   stay_length
# 3               num_unique_units              num_unique_units
# 4                  num_transfers                 num_transfers
# 5              num_cvd_admission             num_cvd_admission
# 6                            CVD                           CVD
# 7     unique_admitting_specialty    unique_admitting_specialty
# 8   unique_discharging_specialty  unique_discharging_specialty
# 9                    DOMICILIARY                   DOMICILIARY
# 10                      MEDICINE                      MEDICINE
# 11                          NHCU                          NHCU
# 12                     NON-COUNT                     NON-COUNT
# 13                        OTHERS                        OTHERS
# ...
