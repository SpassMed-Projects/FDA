# %%
import pandas as pd


import numpy as np
import pandas as pd

import seaborn as sns
from importlib import reload
import matplotlib.pyplot as plt
import preprocess_data 

reload(preprocess_data)

# %matplotlib inline

# %%
inpatients_with_readm = pd.read_csv('/home/daisy/FDA_Dataset/inpatients_with_readm.csv').iloc[:,1:]
measurements_blood_pressure = pd.read_csv('/home/bhatti/dataset/VCHAMPS/measurements_blood_pressure_train.csv').iloc[:,1:]

# %% [markdown]
# # Exploratory Data Analysis

# %%
measurements_blood_pressure
# Out:
#           Internalpatientid  Age at measurement bp       Measurement date  \
# 0                         1              61.554040  2005-10-25 00:02:08.0
# 1                         1              67.037260  2011-04-21 02:50:27.0
# 2                         1              68.304140  2012-07-27 03:54:47.0
# 3                         1              68.347339  2012-08-11 22:51:23.0
# 4                         1              68.781623  2013-01-17 16:23:39.0
# ...                     ...                    ...                    ...
# 21997553              99999              96.324828  2013-03-28 17:23:42.0
# 21997554              99999              96.326070  2013-03-29 04:17:14.0
# 21997555              99999              96.331619  2013-03-31 04:57:36.0
# 21997556              99999              96.357136  2013-04-09 12:47:57.0
# 21997557              99999              96.363892  2013-04-12 00:03:29.0
#
#           Diastolic bp  Systolic bp    State
# 0                 75.0        140.0  Indiana
# 1                 72.0        116.0  Indiana
# 2                100.0        145.0  Indiana
# 3                 89.0        155.0  Indiana
# 4                 72.0        143.0  Indiana
# ...                ...          ...      ...
# 21997553          62.0        147.0  Arizona
# 21997554          57.0        123.0  Arizona
# 21997555          68.0        154.0  Arizona
# 21997556          79.0        147.0  Arizona
# 21997557          52.0        119.0  Arizona
#
# [21997558 rows x 6 columns]

# %%
person = inpatients_with_readm[inpatients_with_readm['Internalpatientid'] == 8]
#person[person['Died during admission']=='Yes']
person
# Out:
#         Internalpatientid  Age at admission         Admission date  \
# 392735                  8         68.544501  2022-08-04 00:21:50.0
#
#                Discharge date Admitting unit service Discharging unit service  \
# 392735  2022-08-25 08:52:17.0               MEDICINE                 MEDICINE
#
#        Admitting specialty    Discharging specialty  \
# 392735       HALFWAY HOUSE  GENERAL(ACUTE MEDICINE)
#
#        First listed discharge diagnosis icd10 subcategory  \
# 392735                         Osteomyelitis, unspecified
#
#        Second listed discharge diagnosis icd10 subcategory  \
# 392735                               Unspecified dementia
#
#        Discharge disposition Died during admission Outpatientreferralflag  \
# 392735               Regular                    No                    Yes
#
#        Serviceconnectedflag Agentorangeflag       State  Hospital readmission
# 392735                  NaN              No  California                     0

# %%
person = measurements_blood_pressure[measurements_blood_pressure['Internalpatientid'] == 10]

sns.scatterplot(x='Age at measurement bp', y='Diastolic bp', data=person, label = 'Diastolic bp')
sns.scatterplot(x='Age at measurement bp', y='Systolic bp', data=person, label ='Systolic bp')
sns.set_theme(style='white', font_scale=10)

# %%
pd.isnull(measurements_blood_pressure).sum() # no Nan values
# Out:
# Internalpatientid        0
# Age at measurement bp    0
# Measurement date         0
# Diastolic bp             0
# Systolic bp              0
# State                    0
# dtype: int64

# %%
sns.histplot(measurements_blood_pressure['Age at measurement bp'])
# Out:
# <Axes: xlabel='Age at measurement bp', ylabel='Count'>

# %%
# prepreocess Measurement date 
measurements_blood_pressure['Measurement date'] = measurements_blood_pressure['Measurement date'].apply(preprocess_data.preprocess_time_string)

# %%
sns.histplot(measurements_blood_pressure['Measurement date'])
# Out:
# <Axes: xlabel='Measurement date', ylabel='Count'>

# %%
sns.histplot(measurements_blood_pressure['Diastolic bp'])
# Out:
# <Axes: xlabel='Diastolic bp', ylabel='Count'>

# %%
sns.histplot(measurements_blood_pressure['Systolic bp'])
# Out:
# <Axes: xlabel='Systolic bp', ylabel='Count'>

# %%
measurements_blood_pressure['State'].value_counts()
# Out:
# Texas                   1882958
# Florida                 1751959
# California              1618878
# New York                1122115
# Ohio                     983518
# Missouri                 942731
# Illinois                 808302
# Pennsylvania             794212
# Tennessee                790882
# North Carolina           615281
# Georgia                  601313
# Wisconsin                535071
# Arizona                  518497
# Michigan                 507291
# West Virginia            499118
# Louisiana                485144
# Virginia                 456767
# Arkansas                 417422
# Oregon                   403929
# Kentucky                 400871
# Puerto Rico              393629
# South Carolina           384843
# Alabama                  380431
# Massachusetts            380143
# Minnesota                377597
# Nebraska                 357697
# Oklahoma                 356005
# Mississippi              305500
# Washington               303333
# Indiana                  292252
# Nevada                   251105
# District of Columbia     228797
# New Jersey               222014
# Maryland                 199702
# New Mexico               177477
# South Dakota             153827
# Colorado                 141112
# Connecticut              128950
# Utah                     125273
# Maine                    107453
# Rhode Island              91515
# Idaho                     90603
# North Dakota              81155
# Wyoming                   73474
# Montana                   60911
# Hawaii                    52891
# Vermont                   48741
# Delaware                  46460
# New Hampshire             35901
# Alaska                    10877
# Not specified              1631
# Name: State, dtype: int64

# %%
measurements_blood_pressure.to_csv('/home/vivi/FDA_datasets/measurements_blood_pressure_preprocessed.csv')
